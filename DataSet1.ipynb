# %%
cd
# Out:
# /Users/danaalmansour

# %%
cd Desktop
# Out:
# /Users/danaalmansour/Desktop

# %%
ls #list - ls
# Out:
# 30368_38700_bundle_archive/
# Average.pdf
# Average.txt
# DAlmansour_701_hw1.doc
# Dana's Python HW1 pdf.pdf
# Dragons tickets.pdf
# HW1.txt
# KU documents/
# Metalica tickets.pdf
# Screen Shot 2020-08-31 at 10.54.10 PM.png
# Screen Shot 2020-08-31 at 11.12.11 PM.png
# Screen Shot 2020-09-07 at 12.32.10 AM.png
# Screen Shot 2020-09-08 at 5.49.13 AM.png
# Screen Shot 2020-09-08 at 9.44.02 PM.png
# bank 2.csv*
# bank-additional-full.csv*
# bank.csv*
# lawrence/
# screen shots/
# ~$#7 cheet sheat.docx
# ~$5 hw 4 Q2.docx
# ~$7 cheet sheat.docx
# ~$C&PE527_PROJECT2_Almansour_Dana.xlsx
# ~$CPE121_20_EMyers.xlsm
# ~$CPE121_HW01_dalmansour.xlsx
# ~$CPE121_HW03_dalmansour.xlsx
# ~$CPE121_HW07_DALMANSOUR.xlsm
# ~$CPE121_HW09_dalmansour.xlsm
# ~$CPE121_PROJECT1_DALMANSOUR 2.xlsx
# ~$CPE121_PROJECT2_dalmansour.xlsm
# ~$CPE121_Project1_dmanzi.xlsx
# ~$CPE121__Project2_dalmansour1.xlsm
# ~$CPE527_PROJECT2_AAli.xlsx
# ~$Dana Excel hw.xlsx
# ~$E Project.docx
# ~$GL 101 RESPONSE 2.docx
# ~$GTS.docx
# ~$HW13.docx
# ~$MATH1.docx
# ~$Song.docx
# ~$actice memo.docx
# ~$ateboard pics.docx
# ~$b Report #1.docx
# ~$creasing atmospheric CO2 on clouds causes marine stratus clouds become more and more unstable until they disappear completely.docx
# ~$cs_files_2012_08_ECS-Example-Resume-BSE.docx
# ~$devesual test sheet.docx
# ~$e you FRACKING kidding me.docx
# ~$eat sheet for twst 1 cpe 522.docx
# ~$eewriting.docx
# ~$fshore Exploration 3.docx
# ~$geol shit.xlsx
# ~$hw3 res.xlsx
# ~$illing project.docx
# ~$na Almansour AAAS paper 1.docx
# ~$na Almansour RESUME first.docx
# ~$na Almansour Resume.docx
# ~$na Almansour draaft.docx
# ~$na Almansour essay                                                                                                                     Almansour.docx
# ~$na Almansour second draftt.docx
# ~$na Almansour_Paper#5.docx
# ~$nal Project Discreption.docx
# ~$rcent Change.docx
# ~$rst draft .docx
# ~$slims Seek New Burial Ground Article.docx
# ~$sx exam 1 cheat sheet.docx
# ~$tRevDraft (2).docx
# ~$thout inquiry.docx
# ~$urnal5.docx
# ~$ver letter first draft.docx
# ~$wer point cheet sheet.docx

# %%
import pandas as pd #manipulating the dataset
import numpy as np # performing numerical calculations
import matplotlib.pyplot as plt #plotting the data
import seaborn as sns #plotting the data

# %%
data = pd.read_csv('bank.csv')

# %%
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
data.marital
# Out:
# 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 11157     single
# 11158    married
# 11159     single
# 11160    married
# 11161    married
# Name: marital, Length: 11162, dtype: object

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
# %matplotlib notebook
data['age'].hist(bins = 100, color = 'blue')
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Frequency')

# %%
dana  = data[data['age'] == 50]

# %%
dana.head()
# Out:
#      age         job   marital  education default  balance housing loan  \
# 84    50      admin.  divorced  secondary      no      363     yes   no
# 189   50  unemployed   married  secondary      no     3674     yes   no
# 251   50  technician   married  secondary      no      416     yes   no
# 266   50    services   married  secondary      no     1595      no   no
# 444   50  technician   married  secondary      no      156      no  yes
#
#       contact  day month  duration  campaign  pdays  previous poutcome deposit
# 84    unknown   16   may      1340         1     -1         0  unknown     yes
# 189   unknown   30   may       886         3     -1         0  unknown     yes
# 251   unknown    5   jun       494         5     -1         0  unknown     yes
# 266   unknown    9   jun       882         1     -1         0  unknown     yes
# 444  cellular   14   jul      1130         3     -1         0  unknown     yes

# %%
data['avg_balance'] = data['balance']/data['age']

# %%
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit  \
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
#
#    avg_balance
# 0    39.711864
# 1     0.803571
# 2    30.975610
# 3    45.018182
# 4     3.407407

# %%
data.isna().sum() #isna() - used to check if the column has null values
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day            0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# deposit        0
# avg_balance    0
# dtype: int64

# %%
data['balance'].dtype
# Out:
# dtype('int64')
